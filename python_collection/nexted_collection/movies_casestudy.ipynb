# %%
movies = [

    ["kgf","kannada",150,2005,8],
    ["balan","malayalam",130,2026,7],
    ["ramayan","hindi",150,2026,8.5],
    ["abcd","malayalam",140,2008,6],
    ["goatlife","malayalam",160,2024,9]
]

# %% [markdown]
# ###Movie Case Study

# %%
movies = [

    ["kgf","kannada",150,2005,8],
    ["balan","malayalam",130,2026,7],
    ["ramayan","hindi",150,2026,8.5],
    ["abcd","malayalam",140,2008,6],
    ["goatlife","malayalam",160,2024,9]
]

# %%
all_mobie_title = {m [0] for m in movies}
all_mobie_title
# Out:
# {'abcd', 'balan', 'goatlife', 'kgf', 'ramayan'}

# %%
movies_languages = {m [1] for m in movies}
movies_languages
# Out:
# {'hindi', 'kannada', 'malayalam'}

# %%
movie_uppercase = {m[0].upper() for m in movies}
movie_uppercase
# Out:
# {'ABCD', 'BALAN', 'GOATLIFE', 'KGF', 'RAMAYAN'}

# %%
name_filter = [m[0] for m in movies if m[0].startswith("a")]
name_filter
# Out:
# ['abcd']

# %%
#display malayalam movies,filter

malayala_movies = [m[0] for m in movies if m[1] =="malayalam"]
malayala_movies
# Out:
# ['balan', 'abcd', 'goatlife']

# %%
#language wise count movies

languages = [m[1] for m in movies]

lc = {l: languages.count(l) for l in languages}
lc
# Out:
# {'kannada': 1, 'malayalam': 3, 'hindi': 1}

# %%
! pip install matplotlib
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import matplotlib.pyplot as plt
x = lc.keys()
y = lc.values()
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt
x = lc.keys()
y = lc.values()
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
x = lc.keys()
y = lc.values()
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
#language wise count movies

languages = [m[1] for m in movies]

lc = {l: languages.count(l) for l in languages}
lc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 #language wise count movies
#       2
# ----> 3 languages = [m[1] for m in movies]
#       4
#       5 lc = {l: languages.count(l) for l in languages}
#       6 lc
#
# NameError: name 'movies' is not defined
