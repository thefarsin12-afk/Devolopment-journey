# %%
from csv import DictReader

fr = open("Cleaned_Viral_Social_Media_Trends.csv","r",encoding="UTF-8")

viral_post = list(DictReader(fr))

unique_platforms = {p.get("Platform") for p in viral_post}

print(unique_platforms)
# Out:
# {'YouTube', 'TikTok', 'Instagram', 'Twitter'}

# %%
#1.Display the Post_ID of every post.

post_id = [p.get("Post_ID") for p in viral_post]
post_id
# Out:
# ['Post_1',
#  'Post_2',
#  'Post_3',
#  'Post_4',
#  'Post_5',
#  'Post_6',
#  'Post_7',
#  'Post_8',
#  'Post_9',
#  'Post_10',
#  'Post_11',
#  'Post_12',
#  'Post_13',
#  'Post_14',
#  'Post_15',
#  'Post_16',
#  'Post_17',
#  'Post_18',
#  'Post_19',
#  'Post_20',
#  'Post_21',
#  'Post_22',
#  'Post_23',
#  'Post_24',
#  'Post_25',
#  'Post_26',
#  'Post_27',
#  'Post_28',
#  'Post_29',
#  'Post_30',
#  'Post_31',
#  'Post_32',
#  'Post_33',
#  'Post_34',
#  'Post_35',
#  'Post_36',
#  'Post_37',
#  'Post_38',
#  'Post_39',
#  'Post_40',
#  'Post_41',
#  'Post_42',
#  'Post_43',
#  'Post_44',
#  'Post_45',
#  'Post_46',
#  'Post_47',
#  'Post_48',
#  'Post_49',
#  'Post_50',
#  'Post_51',
#  'Post_52',
#  'Post_53',
#  'Post_54',
#  'Post_55',
#  'Post_56',
#  'Post_57',
#  'Post_58',
#  'Post_59',
#  'Post_60',
#  'Post_61',
#  'Post_62',
#  'Post_63',
#  'Post_64',
#  'Post_65',
#  'Post_66',
#  'Post_67',
#  'Post_68',
#  'Post_69',
#  'Post_70',
#  'Post_71',
#  'Post_72',
# ...

# %%
#2.Display the Platform of every post.

display_platform = [(p.get("Post_ID"),p.get("Platform")) for p in viral_post]
display_platform
# Out:
# [('Post_1', 'TikTok'),
#  ('Post_2', 'Instagram'),
#  ('Post_3', 'Twitter'),
#  ('Post_4', 'YouTube'),
#  ('Post_5', 'TikTok'),
#  ('Post_6', 'Instagram'),
#  ('Post_7', 'YouTube'),
#  ('Post_8', 'YouTube'),
#  ('Post_9', 'Twitter'),
#  ('Post_10', 'TikTok'),
#  ('Post_11', 'Instagram'),
#  ('Post_12', 'Twitter'),
#  ('Post_13', 'YouTube'),
#  ('Post_14', 'YouTube'),
#  ('Post_15', 'Twitter'),
#  ('Post_16', 'YouTube'),
#  ('Post_17', 'Twitter'),
#  ('Post_18', 'TikTok'),
#  ('Post_19', 'TikTok'),
#  ('Post_20', 'YouTube'),
#  ('Post_21', 'Twitter'),
#  ('Post_22', 'TikTok'),
#  ('Post_23', 'YouTube'),
#  ('Post_24', 'Twitter'),
#  ('Post_25', 'YouTube'),
#  ('Post_26', 'YouTube'),
#  ('Post_27', 'Instagram'),
#  ('Post_28', 'YouTube'),
#  ('Post_29', 'Instagram'),
#  ('Post_30', 'YouTube'),
#  ('Post_31', 'Instagram'),
#  ('Post_32', 'Twitter'),
#  ('Post_33', 'YouTube'),
#  ('Post_34', 'YouTube'),
#  ('Post_35', 'YouTube'),
#  ('Post_36', 'TikTok'),
#  ('Post_37', 'Instagram'),
# ...

# %%
#3.Display the Region of every post.

all_region = [(p.get("Post_ID"),p.get("Region")) for p in viral_post]
all_region
# Out:
# [('Post_1', 'UK'),
#  ('Post_2', 'India'),
#  ('Post_3', 'Brazil'),
#  ('Post_4', 'Australia'),
#  ('Post_5', 'Brazil'),
#  ('Post_6', 'Australia'),
#  ('Post_7', 'Japan'),
#  ('Post_8', 'UK'),
#  ('Post_9', 'India'),
#  ('Post_10', 'India'),
#  ('Post_11', 'Germany'),
#  ('Post_12', 'Australia'),
#  ('Post_13', 'Canada'),
#  ('Post_14', 'Japan'),
#  ('Post_15', 'Germany'),
#  ('Post_16', 'Canada'),
#  ('Post_17', 'UK'),
#  ('Post_18', 'UK'),
#  ('Post_19', 'USA'),
#  ('Post_20', 'UK'),
#  ('Post_21', 'Brazil'),
#  ('Post_22', 'USA'),
#  ('Post_23', 'Brazil'),
#  ('Post_24', 'Japan'),
#  ('Post_25', 'Germany'),
#  ('Post_26', 'Brazil'),
#  ('Post_27', 'India'),
#  ('Post_28', 'Canada'),
#  ('Post_29', 'Canada'),
#  ('Post_30', 'Japan'),
#  ('Post_31', 'Australia'),
#  ('Post_32', 'USA'),
#  ('Post_33', 'USA'),
#  ('Post_34', 'Australia'),
#  ('Post_35', 'UK'),
#  ('Post_36', 'Japan'),
#  ('Post_37', 'Germany'),
#  ('Post_38', 'India'),
#  ('Post_39', 'USA'),
#  ('Post_40', 'USA'),
# ...

# %%
#4.Display the Views of every post.

all_views = [(p.get("Post_ID"),p.get("Views")) for p in viral_post]
all_views
# Out:
# [('Post_1', '4163464'),
#  ('Post_2', '4155940'),
#  ('Post_3', '3666211'),
#  ('Post_4', '917951'),
#  ('Post_5', '64866'),
#  ('Post_6', '1323566'),
#  ('Post_7', '627233'),
#  ('Post_8', '2066886'),
#  ('Post_9', '2169523'),
#  ('Post_10', '3898384'),
#  ('Post_11', '4070332'),
#  ('Post_12', '4585669'),
#  ('Post_13', '4105651'),
#  ('Post_14', '1633015'),
#  ('Post_15', '2471790'),
#  ('Post_16', '3079923'),
#  ('Post_17', '294870'),
#  ('Post_18', '2051091'),
#  ('Post_19', '3461154'),
#  ('Post_20', '3143932'),
#  ('Post_21', '14095'),
#  ('Post_22', '3924406'),
#  ('Post_23', '599766'),
#  ('Post_24', '4357851'),
#  ('Post_25', '731492'),
#  ('Post_26', '4910814'),
#  ('Post_27', '4369260'),
#  ('Post_28', '1874437'),
#  ('Post_29', '1653907'),
#  ('Post_30', '4683280'),
#  ('Post_31', '1365655'),
#  ('Post_32', '2342195'),
#  ('Post_33', '4977438'),
#  ('Post_34', '3005703'),
#  ('Post_35', '936390'),
#  ('Post_36', '1855796'),
#  ('Post_37', '48908'),
# ...

# %%
#5. Display the Likes and Comments of every post.

dispaly_likes_and_comments = [(p.get("Post_ID") ,p.get("Likes"),p.get("Comments"))  for p in viral_post]
dispaly_likes_and_comments
# Out:
# [('Post_1', '339431', '19346'),
#  ('Post_2', '215240', '27239'),
#  ('Post_3', '327143', '36223'),
#  ('Post_4', '127125', '36806'),
#  ('Post_5', '171361', '6376'),
#  ('Post_6', '136282', '47129'),
#  ('Post_7', '84121', '32648'),
#  ('Post_8', '317502', '33638'),
#  ('Post_9', '496078', '30174'),
#  ('Post_10', '8634', '42700'),
#  ('Post_11', '379894', '25242'),
#  ('Post_12', '465871', '8999'),
#  ('Post_13', '195560', '49089'),
#  ('Post_14', '312907', '30725'),
#  ('Post_15', '370802', '17081'),
#  ('Post_16', '124237', '26702'),
#  ('Post_17', '213142', '20767'),
#  ('Post_18', '24472', '41737'),
#  ('Post_19', '165335', '19505'),
#  ('Post_20', '298685', '37162'),
#  ('Post_21', '268310', '16968'),
#  ('Post_22', '35376', '3949'),
#  ('Post_23', '223690', '10538'),
#  ('Post_24', '449803', '28280'),
#  ('Post_25', '474649', '3654'),
#  ('Post_26', '197287', '14896'),
#  ('Post_27', '212278', '18172'),
#  ('Post_28', '322601', '48768'),
#  ('Post_29', '91836', '2823'),
# ...

# %%
#6. Display complete information of every post in a readable format.

for p in viral_post:

 print(p)
# Out:
# {'Post_ID': 'Post_1', 'Post_Date': '2022-01-13', 'Platform': 'TikTok', 'Hashtag': '#Challenge', 'Content_Type': 'Video', 'Region': 'UK', 'Views': '4163464', 'Likes': '339431', 'Shares': '53135', 'Comments': '19346', 'Engagement_Level': 'High'}
# {'Post_ID': 'Post_2', 'Post_Date': '2022-05-13', 'Platform': 'Instagram', 'Hashtag': '#Education', 'Content_Type': 'Shorts', 'Region': 'India', 'Views': '4155940', 'Likes': '215240', 'Shares': '65860', 'Comments': '27239', 'Engagement_Level': 'Medium'}
# {'Post_ID': 'Post_3', 'Post_Date': '2022-01-07', 'Platform': 'Twitter', 'Hashtag': '#Challenge', 'Content_Type': 'Video', 'Region': 'Brazil', 'Views': '3666211', 'Likes': '327143', 'Shares': '39423', 'Comments': '36223', 'Engagement_Level': 'Medium'}
# ...

# %%
#7.Count the total number of posts in the dataset.

print(len(viral_post))
# Out:
# 5000

# %%
#8.Count how many posts are from India.

post_in_india = len([p for p in viral_post if p.get("Region") == "India"])
post_in_india
# Out:
# 617

# %%
#9.Count how many posts are from UK.

post_in_uk = len([p for p in viral_post if p.get("Region") == "UK"])
post_in_uk
# Out:
# 647

# %%
#10.Count how many posts are from Brazil.

post_in_brazil = len([p for p in viral_post if p.get("Region") == "Brazil"])
post_in_brazil
# Out:
# 641

# %%
#11.Count how many posts are from Instagram.

post_in_instagram = len([p for p in viral_post if p.get("Platform") == "Instagram"])
post_in_instagram
# Out:
# 1212

# %%
#12. Count how many posts are from TikTok.

post_in_tiktok = len([p for p in viral_post if p.get("Platform") == "TikTok"])
post_in_tiktok
# Out:
# 1260

# %%
#13.Count how many posts are of Video content type.

video_content_type = len([p for p in viral_post if p.get("Content_Type") == "Video"])
video_content_type
# Out:
# 828

# %%
#14.Count how many posts have High engagement level.

engagement_level = len([p for p in viral_post if p.get("Engagement_Level") == "High"])
engagement_level
# Out:
# 1673

# %%
#15.Find the total number of views across all posts.

total_number_views = sum([int(p.get("Views")) for p in viral_post])
total_number_views
# Out:
# 12470332220

# %%
#16.Find the total number of likes across all posts.

total_number_likes = sum([int(p.get("Likes")) for p in viral_post])
total_number_likes
# Out:
# 1257375149

# %%
#17.Find the total number of shares across all posts.

total_number_of_shares = sum([int(p.get("Shares")) for o in viral_post])
total_number_of_shares
# Out:
# 149725000

# %%
#18.Find the total number of comments across all posts.

total_number_of_comments = sum([int(p.get("Comments")) for p in viral_post])
total_number_of_comments
# Out:
# 124441969

# %%
#19.Find the post with the highest number of views.

highest_number_of_views = max([int(p.get("Views")) for p in viral_post])
highest_number_of_views
# Out:
# 4999430

# %%
#20.Find the post with the lowest number of views.

lowest_number_of_views = min([int(p.get("Views")) for p in viral_post])
lowest_number_of_views
# Out:
# 1266

# %%
#1.Display all posts from India.

all_post_in_india = [p for p in viral_post if p.get("Region") == "India"]
all_post_in_india
# Out:
# [{'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_9',
#   'Post_Date': '2022-09-01',
#   'Platform': 'Twitter',
#   'Hashtag': '#Education',
#   'Content_Type': 'Live Stream',
#   'Region': 'India',
#   'Views': '2169523',
#   'Likes': '496078',
#   'Shares': '96041',
#   'Comments': '30174',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_10',
#   'Post_Date': '2023-01-01',
#   'Platform': 'TikTok',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '3898384',
#   'Likes': '8634',
#   'Shares': '69378',
#   'Comments': '42700',
#   'Engagement_Level': 'Low'},
#  {'Post_ID': 'Post_27',
#   'Post_Date': '2023-05-14',
#   'Platform': 'Instagram',
#   'Hashtag': '#Gaming',
# ...

# %%
#2.Display all posts from Instagram.

instagram_post = [p for p in viral_post if p.get("Platform") == "Instagram"]
instagram_post
# Out:
# [{'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Shorts',
#   'Region': 'Australia',
#   'Views': '1323566',
#   'Likes': '136282',
#   'Shares': '86979',
#   'Comments': '47129',
#   'Engagement_Level': 'Low'},
#  {'Post_ID': 'Post_11',
#   'Post_Date': '2023-08-09',
#   'Platform': 'Instagram',
#   'Hashtag': '#Comedy',
#   'Content_Type': 'Live Stream',
#   'Region': 'Germany',
#   'Views': '4070332',
#   'Likes': '379894',
#   'Shares': '46012',
#   'Comments': '25242',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_27',
#   'Post_Date': '2023-05-14',
#   'Platform': 'Instagram',
# ...

# %%
#3.Display all posts having High engagement level

high_engagement = [p for p in viral_post if p.get("Engagement_Level") == "High"]
high_engagement
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_8',
#   'Post_Date': '2022-01-14',
#   'Platform': 'YouTube',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Shorts',
#   'Region': 'UK',
#   'Views': '2066886',
#   'Likes': '317502',
#   'Shares': '45222',
#   'Comments': '33638',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_11',
#   'Post_Date': '2023-08-09',
#   'Platform': 'Instagram',
#   'Hashtag': '#Comedy',
#   'Content_Type': 'Live Stream',
#   'Region': 'Germany',
#   'Views': '4070332',
#   'Likes': '379894',
#   'Shares': '46012',
#   'Comments': '25242',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_13',
#   'Post_Date': '2022-03-16',
#   'Platform': 'YouTube',
#   'Hashtag': '#Viral',
# ...

# %%
#4.Display all posts having more than 1,000,000 views.

post = [p for p in viral_post if int(p.get("Views")) > 1000000]
post
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
#   'Hashtag': '#Challenge',
# ...

# %%
#5.Display all posts having more than 100,000 likes.

post = [p for p in viral_post if int(p.get("Likes")) > 100000]
post
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_4',
#   'Post_Date': '2022-12-05',
#   'Platform': 'YouTube',
#   'Hashtag': '#Education',
# ...

# %%
#6.Display all posts having more than 50,000 shares.

post = [p for p in viral_post if int(p.get("Shares")) > 50000]
post
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_5',
#   'Post_Date': '2023-03-23',
#   'Platform': 'TikTok',
#   'Hashtag': '#Dance',
#   'Content_Type': 'Post',
#   'Region': 'Brazil',
#   'Views': '64866',
#   'Likes': '171361',
#   'Shares': '69581',
#   'Comments': '6376',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
#   'Hashtag': '#Challenge',
# ...

# %%
#7.Display all posts having more than 20,000 comments.

post = [p for p in viral_post  if int(p.get("Comments")) > 20000]
post
# Out:
# [{'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_4',
#   'Post_Date': '2022-12-05',
#   'Platform': 'YouTube',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'Australia',
#   'Views': '917951',
#   'Likes': '127125',
#   'Shares': '11687',
#   'Comments': '36806',
#   'Engagement_Level': 'Low'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
# ...

# %%
#8.Count the number of posts having more than 1,000,000 views.

post = len([p for p in viral_post if int(p.get("Views")) > 1000000])
post
# Out:
# 3971

# %%
#9.Find the total views generated by posts from India.

post = sum([int(p.get("Views")) for p in viral_post if p.get("Region") == "India"])
post
# Out:
# 1513372283

# %%
#10.Find the total likes generated by posts from Instagram.

post =  sum([int(p.get("Likes")) for p in viral_post if p.get("Platform") == "Instagram"])
print(f"Total likes from instagram = {post}")
# Out:
# Total likes from instagram = 311627280

# %%
#11. Find the total shares generated by TikTok posts.

post = sum([int(p.get("Shares")) for p in viral_post if p.get("Platform") == "TikTok"])
print(f"Total shares in Tiktok = {post}")
# Out:
# Total shares in Tiktok = 64850003

# %%
#12.Find the total comments generated by posts from Brazil.

post = sum([int(p.get("Comments")) for p in viral_post if p.get("Region") == "Brazil"])
print(f"Total comments in brazil = {post}")
# Out:
# Total comments in brazil = 15867659

# %%
#13.Find the average number of views across all posts.

post = [int(p.get("Views")) for p in viral_post]

average = sum(post) / len(post)

print(average)
# Out:
# 2494066.444

# %%
#14.Find the average number of likes across all posts.

post = [int(p.get("Likes")) for p in viral_post]

average = sum(post) / len(post)

print("Average likes",average)
# Out:
# Average likes 251475.0298

# %%
#15.Find the average number of shares across all posts.

post = [int(p.get("Shares")) for p in viral_post]

average = sum(post) / len(post)
print(f"average number of shares = {average}")
# Out:
# average number of shares = 50519.562

# %%
#16.Find the average number of comments across all posts.

post = [int(p.get("Comments")) for p in viral_post]

average = sum(post) / len(post)

print(f"average number of comments = {average}")
# Out:
# average number of comments = 24888.3938

# %%
#17. Find the post having the highest number of likes.

post = max(viral_post,key=lambda p :int(p.get("Likes")))
post
# Out:
# {'Post_ID': 'Post_3134',
#  'Post_Date': '2023-08-06',
#  'Platform': 'TikTok',
#  'Hashtag': '#Fitness',
#  'Content_Type': 'Shorts',
#  'Region': 'Germany',
#  'Views': '2973845',
#  'Likes': '499922',
#  'Shares': '38576',
#  'Comments': '19020',
#  'Engagement_Level': 'High'}

# %%
#18.Find the post having the highest number of shares.

highest_number_of_shares = max(viral_post, key=lambda p:int(p.get("Shares")))
highest_number_of_shares
# Out:
# {'Post_ID': 'Post_792',
#  'Post_Date': '2023-04-30',
#  'Platform': 'TikTok',
#  'Hashtag': '#Music',
#  'Content_Type': 'Tweet',
#  'Region': 'Canada',
#  'Views': '149515',
#  'Likes': '62294',
#  'Shares': '99978',
#  'Comments': '25533',
#  'Engagement_Level': 'Low'}

# %%
#19.Find the post having the highest number of comments.

highest_number_of_comments = max(viral_post,key=lambda p:int(p.get("Comments")))
highest_number_of_comments
# Out:
# {'Post_ID': 'Post_1668',
#  'Post_Date': '2022-08-02',
#  'Platform': 'TikTok',
#  'Hashtag': '#Education',
#  'Content_Type': 'Shorts',
#  'Region': 'Canada',
#  'Views': '295569',
#  'Likes': '56857',
#  'Shares': '20351',
#  'Comments': '49993',
#  'Engagement_Level': 'Medium'}

# %%
#20.Find the post having the lowest number of likes.

lowest_number_of_likes = min(viral_post,key=lambda p:int(p.get("Likes")))
lowest_number_of_likes
# Out:
# {'Post_ID': 'Post_1546',
#  'Post_Date': '2023-07-21',
#  'Platform': 'YouTube',
#  'Hashtag': '#Tech',
#  'Content_Type': 'Reel',
#  'Region': 'UK',
#  'Views': '3101726',
#  'Likes': '490',
#  'Shares': '80829',
#  'Comments': '593',
#  'Engagement_Level': 'High'}

# %%
#21.Count posts having both more than 1,000,000 views and more than 100,000 likes.

post = [p for p in viral_post if int(p.get("Views")) > 1000000 and int(p.get("Likes")) > 100000]
post
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
#   'Hashtag': '#Challenge',
# ...

# %%
#22.Display posts where Views > 2,000,000 and Likes > 200,000.

post = [p for p in viral_post if int(p.get("Views")) > 2000000 and int(p.get("Likes")) > 200000 ]
post
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_8',
#   'Post_Date': '2022-01-14',
#   'Platform': 'YouTube',
#   'Hashtag': '#Gaming',
# ...

# %%
#23.Display posts where Platform is Instagram and Engagement_Level is High.

post = [p for p in viral_post if p.get("Platform") == "Instagram" 
                              and p.get("Engagement_Level") == "High"]
post
# Out:
# [{'Post_ID': 'Post_11',
#   'Post_Date': '2023-08-09',
#   'Platform': 'Instagram',
#   'Hashtag': '#Comedy',
#   'Content_Type': 'Live Stream',
#   'Region': 'Germany',
#   'Views': '4070332',
#   'Likes': '379894',
#   'Shares': '46012',
#   'Comments': '25242',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_46',
#   'Post_Date': '2023-12-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Tweet',
#   'Region': 'Brazil',
#   'Views': '272327',
#   'Likes': '274271',
#   'Shares': '56073',
#   'Comments': '17526',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_64',
#   'Post_Date': '2023-12-05',
#   'Platform': 'Instagram',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Shorts',
#   'Region': 'Canada',
#   'Views': '1142030',
#   'Likes': '212596',
#   'Shares': '72334',
#   'Comments': '18',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_76',
#   'Post_Date': '2023-05-12',
#   'Platform': 'Instagram',
#   'Hashtag': '#Dance',
# ...

# %%
#24.Display posts where Region is India and Content_Type is Video.

post = [p for p in viral_post if p.get("Region") == "India" and p.get("Content_Type") == "Video"]
post
# Out:
# [{'Post_ID': 'Post_27',
#   'Post_Date': '2023-05-14',
#   'Platform': 'Instagram',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Video',
#   'Region': 'India',
#   'Views': '4369260',
#   'Likes': '212278',
#   'Shares': '21264',
#   'Comments': '18172',
#   'Engagement_Level': 'Low'},
#  {'Post_ID': 'Post_38',
#   'Post_Date': '2023-07-15',
#   'Platform': 'Instagram',
#   'Hashtag': '#Dance',
#   'Content_Type': 'Video',
#   'Region': 'India',
#   'Views': '1367820',
#   'Likes': '10794',
#   'Shares': '7617',
#   'Comments': '36639',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_132',
#   'Post_Date': '2023-02-24',
#   'Platform': 'YouTube',
#   'Hashtag': '#Education',
#   'Content_Type': 'Video',
#   'Region': 'India',
#   'Views': '3487375',
#   'Likes': '107303',
#   'Shares': '83451',
#   'Comments': '45313',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_139',
#   'Post_Date': '2023-04-16',
#   'Platform': 'Instagram',
#   'Hashtag': '#Music',
# ...

# %%
#25.Find the total views of posts having High engagement.

post = sum([int(p.get("Views")) for p in viral_post if p.get("Engagement_Level") == "High"])
post
# Out:
# 4093949112

# %%
#1.Find the platform with the highest total views.

platform_views = {}

for p in viral_post:

    platform = p.get("Platform")

    views = int(p.get("Views"))

    if platform not in platform_views:

        platform_views[platform] = views

    else:
        platform_views[platform] += views

highest = max(platform_views, key = lambda p : platform_views [p])

print(highest , ":" ,platform_views[highest])
# Out:
# YouTube : 3370438480

# %%
#2. Find the platform with the highest total likes.

platform_likes = {}

for p in viral_post:

    platform = p.get("Platform")

    likes = int(p.get("Likes"))

    if platform not in platform_likes:

        platform_likes[platform] = likes

    else:

        platform_likes[platform] += likes

highest_likes = max(platform_likes , key= lambda p:platform_likes[p])           

print(highest_likes , ":" , platform_likes[highest_likes])
# Out:
# YouTube : 342007739

# %%
#3.Find the platform with the highest total shares.

platform_shares = {}

for p in viral_post:

    platform = p.get("Platform")

    shares = int(p.get("Shares"))

    if platform not in platform_shares:

        platform_shares[platform] = shares

    else:
        platform_shares[platform] += shares

highest_shares = max(platform_shares,key=lambda p:platform_shares[p])

print(highest_shares,":",platform_shares[highest_shares])
# Out:
# YouTube : 66296773

# %%
#4.Find the region with the highest total views.

region_total_views = {}

for p in viral_post:

    region = p.get("Region")

    views = int(p.get("Views"))

    if region not in region_total_views:

        region_total_views[region] = views

    else:
        region_total_views[region] += views

highest = max(region_total_views,key=lambda p:region_total_views[p])

print(highest,":",region_total_views[highest])
# Out:
# USA : 1756951739

# %%
#5.Find the region with the highest total likes.

region_total_likes = {}

for p in viral_post:

    region = p.get("Region")

    likes = int(p.get("Likes"))

    if region not in region_total_likes:

        region_total_likes[region] = likes

    else:
        region_total_likes[region] += likes


highest_likes = max(region_total_likes,key=lambda p:region_total_likes[p])

print(highest_likes,":",region_total_likes[highest_likes])
# Out:
# Canada : 168585301

# %%
#6.Find the most commonly used hashtag.

count_hashtag = {}

for p in viral_post:

    hashtag = p.get("Hashtag")

    if hashtag not in count_hashtag:

        count_hashtag[hashtag] = 1

    else:
        count_hashtag[hashtag] += 1

common = max(count_hashtag,key=lambda p:count_hashtag[p])

print(common,":",count_hashtag[common])
# Out:
# #Fitness : 536

# %%
#7.Find the most commonly used content type.

content_type = {}

for p in viral_post:

    content = p.get("Content_Type")

    if content not in content_type:

        content_type[content] = 1

    else:
        content_type[content] += 1

common = max(content_type , key=lambda p:content_type[p])

print(common,":",content_type[common])
# Out:
# Live Stream : 855

# %%
#8.Find the most common engagement level.

most_engagemet = {}

for p in viral_post:

    engagement_l = p.get("Engagement_Level")

    if engagement_l not in most_engagemet:

        most_engagemet[engagement_l] = 1

    else:

        most_engagemet[engagement_l] += 1

common = max(most_engagemet,key=lambda p:most_engagemet[p])

print(common,":",most_engagemet[common])
# Out:
# Low : 1729

# %%
#9. Calculate the engagement score for every post using
# Likes + Shares + Comments. Display Post_ID and Engagement Score.

for p in viral_post:

 engagement_score = (
  
                    int(p.get("Likes")) +
                    int(p.get("Shares")) +
                    int(p.get("Comments"))

                    )
print(p.get("Post_ID"),":",engagement_score)
# Out:
# Post_5000 : 149070

# %%
#10. Find the post with the highest engagement score.
engement_score = [
    (
        p,

        int(p.get("Likes")) +
        int(p.get("Shares")) +
        int(p.get("Comments"))
    )

    for p in viral_post
]


highest = max(engement_score, key=lambda x:x[1])

print(highest[0].get("Post_ID"),":",highest[1])
# Out:
# Post_2908 : 635139
