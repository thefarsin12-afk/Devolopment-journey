# %%
# index method

name = "alexander"
print(name.index())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # index method
#       3 name = "alexander"
# ----> 4 print(name.index())
#
# TypeError: index expected at least 1 argument, got 0

# %%
print("Hellow world")
# Out:
# Hellow world

# %%
name = "rahul"
print(name.startswith("ra")
# Out:
#   Cell In[7], line 2
#     print(name.startswith("ra")
#                                ^
# _IncompleteInputError: incomplete input

# %%
text = "i hate python"

update_text = text.replace("hate","love")

print(update_text)
# Out:
# i love python

# %%
name = "@Jhonson1"

update_name = name.strip("@1")

print(update_name)
# Out:
# Jhonson
